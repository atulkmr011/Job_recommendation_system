# %% [markdown]
# # Little more cleaning to to avoid crashing of system in training

# %% [markdown]
# # Grouping the columns

# %%
#import libraries
import pandas as pd
import neattext.functions as nfx

# %%
df=pd.read_csv('after_vis_naukri_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                     company  \
# 0           0                            MM Media Pvt Ltd
# 1           1         Softtech Career Infosystem Pvt. Ltd
# 2           2                      Onboard HRServices LLP
# 3           3  Spire Technologies and Solutions Pvt. Ltd.
# 4           4             PFS Web Global Services Pvt Ltd
#
#                                            education  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...
# 1  UG: Any Graduate - Any Specialization PG:Any P...
# 2  UG: Any Graduate - Any Specialization PG:CA Do...
# 3  UG: B.Tech/B.E. - Any Specialization PG:Any Po...
# 4  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...
#
#                                            Job Title  \
# 0           Walkin Data Entry Operator (night Shift)
# 1                             Pl/sql Developer - SQL
# 2             Manager/ad/partner - Indirect Tax - CA
# 3                    JAVA Technical Lead (6-8 yrs) -
# ...

# %%
df['Job Title'] = df['Job Title'].apply(nfx.remove_emails)
df['Job Title'] = df['Job Title'].apply(nfx.remove_phone_numbers)
df['Job Title'] = df['Job Title'].str.replace('Whatsapp', '').str.replace('whatsapp', '').str.replace('India', '')
df['Job Title'] = df['Job Title'].str.replace('bangalore', '').str.replace('Delhi/NCR', '').str.replace('Hyderabad', '')
df['Job Title'] = df['Job Title'].str.replace('Bangalore', '').str.replace('Walkin', '').str.replace('WALK IN', '')
df['Job Title'] = df['Job Title'].str.replace('Chennai', '').str.replace('walkin', '').str.replace('walk in', '')
df['Job Title'] = df['Job Title'].str.replace('Ahemdabaad', '').str.replace('Walk in', '').str.replace('Salary', '').str.replace('salary', '')
df['Job Title'] = df['Job Title'].str.replace('Mumbai', '').str.replace('(night Shift)', '').str.replace('Shift', '').str.replace('DAY', '').str.replace('Day', '').str.replace('day', '')
df['Job Title'] = df['Job Title'].str.replace('Pune', '').str.replace('(Night Shift)', '').str.replace('(Day Shift)', '')
df['Job Title'] = df['Job Title'].str.replace('Ã', '').str.replace('Â -Ã', '')
df['Job Title'] = df['Job Title'].str.replace('years','').str.replace('yrs','').str.replace('Years','').str.replace('Year','')
df['Job Title'] = df['Job Title'].str.replace('()','').str.replace('-','').str.replace('Year','')
df['Job Title'] = df['Job Title'].apply(nfx.remove_numbers).apply(nfx.remove_stopwords).apply(nfx.remove_special_characters)

# %%
df.head()
# Out:
#    Unnamed: 0                                     company  \
# 0           0                            MM Media Pvt Ltd
# 1           1         Softtech Career Infosystem Pvt. Ltd
# 2           2                      Onboard HRServices LLP
# 3           3  Spire Technologies and Solutions Pvt. Ltd.
# 4           4             PFS Web Global Services Pvt Ltd
#
#                                            education  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...
# 1  UG: Any Graduate - Any Specialization PG:Any P...
# 2  UG: Any Graduate - Any Specialization PG:CA Do...
# 3  UG: B.Tech/B.E. - Any Specialization PG:Any Po...
# 4  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...
#
#                            Job Title  \
# 0               Data Entry Operator
# 1                Plsql Developer SQL
# 2      Manageradpartner Indirect Tax
# 3              JAVA Technical Lead
# 4  Developer Pfsweb Global Services
#
#                                       jobdescription  \
# ...

# %%
df['comb1'] = df['jobdescription']
df['comb2'] = df['education'] + ' ' + df['jobdescription']
df['comb3'] = df['education'] + ' ' + df['jobdescription'] + ' '+ df['Key Skills']
df['comb4'] = df['education'] + ' ' + df['jobdescription'] + ' '+ df['Key Skills'] + ' '+ df['Job Title']
df['comb5'] = df['education'] + ' ' + df['jobdescription'] + ' '+ df['Key Skills'] + ' '+ df['Job Title'] + ' '+ df['Location']
df['comb6'] = df['jobdescription'] + ' '+ df['Key Skills']
df['comb7'] = df['jobdescription'] + ' '+ df['Key Skills'] + ' '+ df['Job Title']
df['comb8'] = df['jobdescription'] + ' '+ df['Job Title']

# %%
df['comb1'] = df['comb1'].str.lower()
df['comb2'] = df['comb2'].str.lower()
df['comb3'] = df['comb3'].str.lower()
df['comb4'] = df['comb4'].str.lower()
df['comb5'] = df['comb5'].str.lower()
df['comb6'] = df['comb6'].str.lower()
df['comb7'] = df['comb7'].str.lower()
df['comb8'] = df['comb8'].str.lower()

# %%
df.head()
# Out:
#    Unnamed: 0                                     company  \
# 0           0                            MM Media Pvt Ltd
# 1           1         Softtech Career Infosystem Pvt. Ltd
# 2           2                      Onboard HRServices LLP
# 3           3  Spire Technologies and Solutions Pvt. Ltd.
# 4           4             PFS Web Global Services Pvt Ltd
#
#                                            education  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...
# 1  UG: Any Graduate - Any Specialization PG:Any P...
# 2  UG: Any Graduate - Any Specialization PG:CA Do...
# 3  UG: B.Tech/B.E. - Any Specialization PG:Any Po...
# 4  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...
#
#                            Job Title  \
# 0               Data Entry Operator
# 1                Plsql Developer SQL
# 2      Manageradpartner Indirect Tax
# 3              JAVA Technical Lead
# 4  Developer Pfsweb Global Services
#
#                                       jobdescription  \
# ...

# %%
df['comb1'] = df['comb1'].apply(nfx.remove_emails)
df['comb2'] = df['comb2'].apply(nfx.remove_emails)
df['comb3'] = df['comb3'].apply(nfx.remove_emails)
df['comb4'] = df['comb4'].apply(nfx.remove_emails)
df['comb5'] = df['comb5'].apply(nfx.remove_emails)
df['comb6'] = df['comb6'].apply(nfx.remove_emails)
df['comb7'] = df['comb7'].apply(nfx.remove_emails)
df['comb8'] = df['comb8'].apply(nfx.remove_emails)
df['comb1'] = df['comb1'].apply(nfx.remove_stopwords)
df['comb2'] = df['comb2'].apply(nfx.remove_stopwords)
df['comb3'] = df['comb3'].apply(nfx.remove_stopwords)
df['comb4'] = df['comb4'].apply(nfx.remove_stopwords)
df['comb5'] = df['comb5'].apply(nfx.remove_stopwords)
df['comb6'] = df['comb6'].apply(nfx.remove_stopwords)
df['comb7'] = df['comb7'].apply(nfx.remove_stopwords)
df['comb8'] = df['comb8'].apply(nfx.remove_stopwords)

# %%
df['comb1'] = df['comb1'].apply(nfx.remove_special_characters)
df['comb2'] = df['comb2'].apply(nfx.remove_special_characters)
df['comb3'] = df['comb3'].apply(nfx.remove_special_characters)
df['comb4'] = df['comb4'].apply(nfx.remove_special_characters)
df['comb5'] = df['comb5'].apply(nfx.remove_special_characters)
df['comb6'] = df['comb6'].apply(nfx.remove_special_characters)
df['comb7'] = df['comb7'].apply(nfx.remove_special_characters)
df['comb8'] = df['comb8'].apply(nfx.remove_special_characters)

# %%
df['comb1'] = df['comb1'].apply(nfx.remove_phone_numbers).apply(nfx.remove_non_ascii)
df['comb2'] = df['comb2'].apply(nfx.remove_phone_numbers).apply(nfx.remove_non_ascii)
df['comb3'] = df['comb3'].apply(nfx.remove_phone_numbers).apply(nfx.remove_non_ascii)
df['comb4'] = df['comb4'].apply(nfx.remove_phone_numbers).apply(nfx.remove_non_ascii)
df['comb5'] = df['comb5'].apply(nfx.remove_phone_numbers).apply(nfx.remove_non_ascii)
df['comb6'] = df['comb6'].apply(nfx.remove_phone_numbers).apply(nfx.remove_non_ascii)
df['comb7'] = df['comb7'].apply(nfx.remove_phone_numbers).apply(nfx.remove_non_ascii)
df['comb8'] = df['comb8'].apply(nfx.remove_phone_numbers).apply(nfx.remove_non_ascii)

# %%
df.head()
# Out:
#    Unnamed: 0                                     company  \
# 0           0                            MM Media Pvt Ltd
# 1           1         Softtech Career Infosystem Pvt. Ltd
# 2           2                      Onboard HRServices LLP
# 3           3  Spire Technologies and Solutions Pvt. Ltd.
# 4           4             PFS Web Global Services Pvt Ltd
#
#                                            education  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...
# 1  UG: Any Graduate - Any Specialization PG:Any P...
# 2  UG: Any Graduate - Any Specialization PG:CA Do...
# 3  UG: B.Tech/B.E. - Any Specialization PG:Any Po...
# 4  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...
#
#                            Job Title  \
# 0               Data Entry Operator
# 1                Plsql Developer SQL
# 2      Manageradpartner Indirect Tax
# 3              JAVA Technical Lead
# 4  Developer Pfsweb Global Services
#
#                                       jobdescription  \
# ...

# %%
df['comb1'] = df['comb1'].apply(nfx.remove_emails).apply(nfx.remove_currency_symbols).apply(nfx.remove_punctuations)
df['comb2'] = df['comb2'].apply(nfx.remove_emails).apply(nfx.remove_currency_symbols).apply(nfx.remove_punctuations)
df['comb3'] = df['comb3'].apply(nfx.remove_emails).apply(nfx.remove_currency_symbols).apply(nfx.remove_punctuations)
df['comb4'] = df['comb4'].apply(nfx.remove_emails).apply(nfx.remove_currency_symbols).apply(nfx.remove_punctuations)
df['comb5'] = df['comb5'].apply(nfx.remove_emails).apply(nfx.remove_currency_symbols).apply(nfx.remove_punctuations)
df['comb6'] = df['comb6'].apply(nfx.remove_emails).apply(nfx.remove_currency_symbols).apply(nfx.remove_punctuations)
df['comb7'] = df['comb7'].apply(nfx.remove_emails).apply(nfx.remove_currency_symbols).apply(nfx.remove_punctuations)
df['comb8'] = df['comb8'].apply(nfx.remove_emails).apply(nfx.remove_currency_symbols).apply(nfx.remove_punctuations)

# %%
df['comb1'] = df['comb1'].str.replace('job description send jobs like', '').str.replace('specialization', '')
df['comb2'] = df['comb2'].str.replace('job description send jobs like', '').str.replace('specialization', '')
df['comb3'] = df['comb3'].str.replace('job description send jobs like', '').str.replace('specialization', '')
df['comb4'] = df['comb4'].str.replace('job description send jobs like', '').str.replace('specialization', '')
df['comb5'] = df['comb5'].str.replace('job description send jobs like', '').str.replace('specialization', '')
df['comb6'] = df['comb6'].str.replace('job description send jobs like', '').str.replace('specialization', '')
df['comb7'] = df['comb7'].str.replace('job description send jobs like', '').str.replace('specialization', '')
df['comb8'] = df['comb8'].str.replace('send jobs like', '')
df['comb1'] = df['comb1'].str.replace('send jobs like', '')
df['comb2'] = df['comb2'].str.replace('send jobs like', '')
df['comb3'] = df['comb3'].str.replace('send jobs like', '')
df['comb4'] = df['comb4'].str.replace('send jobs like', '')
df['comb5'] = df['comb5'].str.replace('send jobs like', '')
df['comb6'] = df['comb6'].str.replace('send jobs like', '')
df['comb7'] = df['comb7'].str.replace('send jobs like', '')
df['comb8'] = df['comb8'].str.replace('send jobs like', '')

# %%
df['comb1'] = df['comb1'].str.replace('job description', '')
df['comb2'] = df['comb2'].str.replace('job description', '')
df['comb3'] = df['comb3'].str.replace('job description', '')
df['comb4'] = df['comb4'].str.replace('job description', '')
df['comb5'] = df['comb5'].str.replace('job description', '')
df['comb6'] = df['comb6'].str.replace('job description', '')
df['comb7'] = df['comb7'].str.replace('job description', '')
df['comb8'] = df['comb8'].str.replace('job description', '')

# %%
df.head()
# Out:
#    Unnamed: 0                                     company  \
# 0           0                            MM Media Pvt Ltd
# 1           1         Softtech Career Infosystem Pvt. Ltd
# 2           2                      Onboard HRServices LLP
# 3           3  Spire Technologies and Solutions Pvt. Ltd.
# 4           4             PFS Web Global Services Pvt Ltd
#
#                                            education  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...
# 1  UG: Any Graduate - Any Specialization PG:Any P...
# 2  UG: Any Graduate - Any Specialization PG:CA Do...
# 3  UG: B.Tech/B.E. - Any Specialization PG:Any Po...
# 4  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...
#
#                            Job Title  \
# 0               Data Entry Operator
# 1                Plsql Developer SQL
# 2      Manageradpartner Indirect Tax
# 3              JAVA Technical Lead
# 4  Developer Pfsweb Global Services
#
#                                       jobdescription  \
# ...

# %%
df.to_csv("naukri_data_with_combo.csv")
